# %%
import pandas as pd
import arcpy
from arcgis.features import FeatureLayer

# %%
# Gets data from the TRPA server
def get_fs_data(service_url):
    feature_layer = FeatureLayer(service_url)
    query_result = feature_layer.query()
    # Convert the query result to a list of dictionaries
    feature_list = query_result.features
    # Create a pandas DataFrame from the list of dictionaries
    all_data = pd.DataFrame([feature.attributes for feature in feature_list])
    # return data frame
    return all_data

# %% [markdown]
# # Import parcels layer, hex bins and census blocks and block groups

# %% [markdown]
# # Filter Parcels to exclude open space, recreation ect
# # Create a new feature layer with one shape that's "residential zone"
# # Create a new block layer that does a spatial join to the "residential zone and only keeps portions of the block within that zone
# # Create a new hex layer that only includes bins with the majority? within the residential zone
# # Join that hex layer to the block layer and assign each hex bin a block number based on the the block group it falls most within
# # Do density calculations for variables of interest with these new block groups
# # Need to decide if we should do population weighted interpolation of block group level data to these blocks?
# # Blocks would have a "Block group id and a block group proportion
